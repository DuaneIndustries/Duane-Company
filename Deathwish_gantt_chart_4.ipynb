# %% [markdown]
#  # Duane and Company

# %% [markdown]
# ### Deathwish Coffee Project - Phase II Schedule

# %%
import pandas as pd
import plotly.express as px

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# <div>                            <div id="c625f2a4-8bc5-402c-9094-44238525f29e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c625f2a4-8bc5-402c-9094-44238525f29e")) {                    Plotly.newPlot(                        "c625f2a4-8bc5-402c-9094-44238525f29e",                        [{"alignmentgroup": "True", "base": ["2021-04-05", "2021-04-26", "2021-07-06"], "hovertemplate": "Resource=Equipment<br>Start=%{base}<br>Finish=%{x}<br>Task=%{y}<extra></extra>", "legendgroup": "Equipment", "marker": {"color": "#636efa"}, "name": "Equipment", "offsetgroup": "Equipment", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [345600000.0, 345600000.0, 259200000.0], "xaxis": "x", "y": ["Fabricate Young Blender support fr
# ...
